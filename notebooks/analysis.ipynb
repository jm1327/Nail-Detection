# %%
import pandas as pd

df = pd.read_csv("../results/model_summary.csv")
df.head(20)
# Out:
#                                           model  epoch  best mAP50-95  \
# 0   yolo26n_AdamW_lr0.003_b8_mosaic0_coslrfalse   66.0        0.48839
# 1                       yolo26l_img640_auto_b16   50.0        0.48716
# 2                        yolo26l_img640_auto_b8   50.0        0.48716
# 3                 yolo26m_sub320_img640_auto_b8  123.0        0.47826
# 4                               yolo26x-default   51.0        0.47626
# 5                        yolo26l_img640_auto_b4   97.0        0.47497
# 6    yolo26n_Adam_lr0.003_b8_mosaic0_coslrfalse   63.0        0.47422
# 7    yolo26n_AdamW_lr0.001_b8_mosaic0_coslrtrue   37.0        0.47416
# 8   yolo26n_MuSGD_lr0.005_b8_mosaic0_coslrfalse   50.0        0.47030
# 9                        yolo26n_img640_auto_b8   92.0        0.46946
# 10   yolo26n_NAdam_lr0.002_b8_mosaic0_coslrtrue   31.0        0.46571
# 11                              yolo26m-dedault   51.0        0.46518
# ...
